# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")

vacation_df
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 0          0           Touros      BR     79.88       broken clouds  -5.1989
# 1          3       Tinaquillo      VE     77.07          light rain   9.9186
# 2         11          Rikitea      PF     78.42           clear sky -23.1203
# 3         12            Vaini      TO     84.36       broken clouds -21.2000
# 4         13          Labuhan      ID     79.65    scattered clouds  -6.8844
# 5         14            Gamba      GA     77.52     overcast clouds  -2.6500
# 6         17          Kavieng      PG     85.24       broken clouds  -2.5744
# 7         19        Mahebourg      MU     77.29       broken clouds -20.4081
# 8         33        Teluknaga      ID     80.64          light rain  -6.0989
# 9         37           Atuona      PF     79.74           clear sky  -9.8000
# 10        39      Madanapalle      IN     77.47       broken clouds  13.5500
# 11        41       Georgetown      MY     82.33    scattered clouds   5.4112
# 12        46           Lompoc      US     75.69           clear sky  34.6391
# 13        55           Gadwal      IN     83.82          light rain  16.2333
# 14        60     Quatre Cocos      MU     77.11          light rain -20.2078
# 15        64             Hilo      US     78.53       moderate rain  19.7297
# 16        65        Mount Isa      AU     76.77           clear sky -20.7333
# 17        69        Hithadhoo      MV     82.53       broken clouds  -0.6000
# 18        72            Houma      US     83.01    scattered clouds  29.5958
# 19        75              Gat      IL     88.48          few clouds  31.6100
# 20        82           Majene      ID     78.69     overcast clouds  -3.5403
# 21        86        Sinnamary      GF     77.54       broken clouds   5.3833
# 22        89           Lobito      AO     77.05          light rain -12.3481
# 23        92         Cabedelo      BR     81.27       broken clouds  -6.9811
# 24        94         Bengkulu      ID     76.08     overcast clouds  -3.8004
# 25        95           Olinda      BR     83.93          few clouds  -8.0089
# 26        98       Vila Velha      BR     76.95       broken clouds -20.3297
# 27        99           Lethem      GY     84.99    scattered clouds   3.3803
# 28       103     San Patricio      US     89.69          few clouds  28.0170
# 29       104           Avarua      CK     82.45     overcast clouds -21.2078
# 30       105           Kokoda      PG     81.45     overcast clouds  -8.8785
# 31       109            Kapaa      US     78.78          light rain  22.0752
# 32       113          Malayal      PH     78.60     overcast clouds   7.2080
# 33       115          Prainha      BR     76.14       moderate rain  -1.8000
# 34       119  Bandar-E Lengeh      IR     76.69           clear sky  26.5579
# 35       121         Garautha      IN     87.15           clear sky  25.5667
# 36       124          Samarai      PG     82.22       moderate rain -10.6167
# 37       125      Port-Gentil      GA     80.56       broken clouds  -0.7193
# 38       128     Puerto Ayora      EC     78.76          light rain  -0.7393
# 39       131        Bathsheba      BB     81.21    scattered clouds  13.2167
# 40       132            Dutse      NG     81.57          light rain  11.7594
# 41       133             Poso      ID     77.90       broken clouds  -1.3959
# 42       135            Wewak      PG     82.18       broken clouds  -3.5534
# 43       137              Vao      NC     76.91    scattered clouds -22.6667
# 44       138           Lokoja      NG     76.98          light rain   7.8024
# 45       146          Oistins      BB     80.69    scattered clouds  13.0667
# 46       147             Daru      PG     81.95     overcast clouds  -9.0763
# 47       148      Dicabisagan      PH     76.23     overcast clouds  17.0818
# 48       150        Caravelas      BR     77.79     overcast clouds -17.7125
# 49       152             Auki      SB     82.98     overcast clouds  -8.7676
# 50       156  Bambous Virieux      MU     77.25          light rain -20.3428
# 51       161           Padang      ID     75.25       moderate rain  -0.9492
# 52       166     Kudahuvadhoo      MV     83.64     overcast clouds   2.6708
# 53       168        Namatanai      PG     84.58          light rain  -3.6667
# 54       169           Harper      LR     77.18     overcast clouds   4.3750
# 55       170       Butaritari      KI     81.77          few clouds   3.0707
# 56       174            Buala      SB     83.34          light rain  -8.1450
# 57       175           Bonthe      SL     78.98     overcast clouds   7.5264
# 58       177         Lorengau      PG     82.76       broken clouds  -2.0226
# 59       187        Ratnagiri      IN     79.95           clear sky  16.9833
# 60       188            Basco      PH     76.59     overcast clouds  20.4487
# 61       189            Seidu      SL     75.27     overcast clouds   9.0167
# 62       191          Tikapur      NP     75.42    scattered clouds  28.5000
# 63       198     Isla Mujeres      MX     84.16           clear sky  21.2311
# 64       203     Saint George      US     84.25           clear sky  37.1041
# 65       204       Maningrida      AU     77.09     overcast clouds -12.0667
# 66       210  Manavalakurichi      IN     80.60       broken clouds   8.1333
# 67       219            Alofi      NU     85.89     overcast clouds -19.0595
# 68       233          Ternate      ID     81.28    scattered clouds   0.8000
# 69       235        Road Town      VG     80.69    scattered clouds  18.4167
# 70       237           Najran      SA     75.85       broken clouds  17.4924
# 71       238     Port Moresby      PG     80.02          few clouds  -9.4431
# 72       239           Goundi      TD     88.57     overcast clouds   9.3627
# 73       241        Boyolangu      ID     76.01     overcast clouds  -8.1181
# 74       242           Matara      LK     78.91     overcast clouds   5.9485
# 75       245       La Carlota      PH     79.65       broken clouds  10.4233
# 76       251             Gizo      SB     83.19          light rain  -8.1030
# 77       259           Neiafu      TO     83.08    scattered clouds -18.6500
# 78       261            Matay      EG     85.60     overcast clouds  28.4190
# 79       263           Faanui      PF     81.03          light rain -16.4833
# 80       264         Coruripe      BR     80.53          light rain -10.1256
# 81       269       Singkawang      ID     76.32          light rain   0.9000
# 82       271       Lahad Datu      MY     76.05       broken clouds   5.0268
# 83       275       Alamogordo      US     86.40           clear sky  32.8995
# 84       276      Muzaffarpur      IN     75.31           clear sky  26.1167
# 85       277          Honavar      IN     79.36          few clouds  14.2833
# 86       281            Aswan      EG     85.30           clear sky  24.0934
# 87       293       Banda Aceh      ID     78.37     overcast clouds   5.5577
# 88       295          Salalah      OM     78.55          few clouds  17.0151
# 89       296           Cairns      AU     80.55    scattered clouds -16.9167
# 90       298         Souillac      MU     77.38       broken clouds -20.5167
# 91       303            Prado      BR     76.98     overcast clouds -17.3411
# 92       306            Birao      CF     85.71       broken clouds  10.2849
# 93       309      La Asuncion      VE     82.13     overcast clouds  11.0333
# 94       315          Manaure      CO     85.57     overcast clouds  11.7751
# 95       317              Ler      SS     83.10           clear sky   8.3018
# 96       318   Kulhudhuffushi      MV     83.61     overcast clouds   6.6221
# 97       328            Minna      NG     78.30          light rain   9.6139
# 98       329          Kuching      MY     77.22    scattered clouds   1.5500
# 99       331        Ugoofaaru      MV     83.73     overcast clouds   5.6667
# 100      332          Inirida      CO     75.20     overcast clouds   3.8653
# 101      337         Celestun      MX     82.22           clear sky  20.8667
# 102      338    San Cristobal      VE     75.38     overcast clouds   7.7669
# 103      344           Bauchi      NG     77.56          light rain  10.5000
# 104      347            Hobyo      SO     82.98          light rain   5.3505
# 105      349     Stephenville      US     84.33           clear sky  32.2207
# 106      352           Palasa      IN     79.14     overcast clouds  18.7667
# 107      357          Mareeba      AU     75.92     overcast clouds -17.0000
# 108      358       Port Blair      IN     80.62       broken clouds  11.6667
# 109      363       Hambantota      LK     79.38     overcast clouds   6.1241
# 110      365         Paracuru      BR     82.11     overcast clouds  -3.4100
# 111      366          Isangel      VU     82.06       moderate rain -19.5500
# 112      370      Salinopolis      BR     78.15       moderate rain  -0.6136
# 113      371         Umm Lajj      SA     83.84     overcast clouds  25.0213
# 114      372            Avera      US     77.05     overcast clouds  33.1940
# 115      377   Cap Malheureux      MU     75.47    scattered clouds -19.9842
# 116      378       Sadasivpet      IN     79.70       broken clouds  17.6212
# 117      379              Sur      OM     85.17           clear sky  22.5667
# 118      384           Ouidah      BJ     84.06          light rain   6.3631
# 119      389        Riberalta      BO     82.60       broken clouds -10.9833
# 120      390         Araguacu      BR     75.47       broken clouds -12.9306
# 121      391         Am Timan      TD     89.89       broken clouds  11.0297
# 122      401        San Diego      US     77.72           clear sky  32.7153
# 123      403         Meulaboh      ID     77.25     overcast clouds   4.1363
# 124      405        Srandakan      ID     77.02     overcast clouds  -7.9386
# 125      408      Kloulklubed      PW     82.17     overcast clouds   7.0419
# 126      412        Dickinson      US     87.10    scattered clouds  29.4608
# 127      416          Kahului      US     82.42    scattered clouds  20.8947
# 128      420        Kununurra      AU     76.98    scattered clouds -15.7667
# 129      425             Tual      ID     84.54     overcast clouds  -5.6667
# 130      429       New Iberia      US     82.06    scattered clouds  30.0035
# 131      433           Dingle      PH     77.92       broken clouds  10.9995
# 132      434      Black River      JM     79.66          few clouds  18.0264
# 133      437           Ixtapa      MX     88.93       broken clouds  20.7000
# 134      439           Sampit      ID     75.18       broken clouds  -2.5333
# 135      441        Kavaratti      IN     82.74       broken clouds  10.5669
# 136      452             Yaan      NG     80.35          light rain   7.3833
# 137      453    Pangkalanbuun      ID     75.13     overcast clouds  -2.6833
# 138      460       Santa Cruz      BO     75.25       broken clouds -17.8000
# 139      462           Vanimo      PG     80.67     overcast clouds  -2.6741
# 140      466              Eyl      SO     82.04    scattered clouds   7.9803
# 141      469           Pangai      TO     84.31    scattered clouds -19.8000
# 142      470            Manta      EC     85.78    scattered clouds  -0.9500
# 143      471        Boa Vista      BR     89.58       broken clouds   2.8197
# 144      472         Barahona      DO     76.82       broken clouds  18.2085
# 145      476          Iquitos      PE     75.24       broken clouds  -3.7481
# 146      482        Manokwari      ID     81.63     overcast clouds  -0.8667
# 147      483          Lafiagi      NG     78.40       moderate rain   8.8667
# 148      501          Tautira      PF     81.30          few clouds -17.7333
# 149      505          Bubaque      GW     75.20    scattered clouds  11.2833
# 150      506         Karratha      AU     81.79          few clouds -20.7377
# 151      508      Grand Gaube      MU     77.40    scattered clouds -20.0064
# 152      513       Carutapera      BR     76.66       moderate rain  -1.1950
# 153      514    Makakilo City      US     79.12       broken clouds  21.3469
# 154      515            Tabou      CI     76.95     overcast clouds   4.4230
# 155      526      Brownsville      US     89.10           clear sky  25.9018
# 156      527             Sola      VU     82.06       broken clouds -13.8833
# 157      529          Itarema      BR     77.92     overcast clouds  -2.9248
# 158      533           Katobu      ID     77.04     overcast clouds  -4.9408
# 159      535       Vertientes      CU     80.04    scattered clouds  21.2594
# 160      542           Karwar      IN     78.55          few clouds  14.8000
# 161      550          Pitimbu      BR     81.19       broken clouds  -7.4706
# 162      552   Boca Del Monte      MX     88.61           clear sky  19.1500
#
#           Lng                                         Hotel Name
# 0    -35.4608                                    INN NEW HORIZON
# 1    -68.3047                                 Hotel Los Copihues
# 2   -134.9692                                    People ThankYou
# 3   -175.2000                                Keleti Beach Resort
# 4    112.2051                                          DoubleFAG
# 5     10.0000                                                NaN
# 6    150.7967                                Nusa Island Retreat
# 7     57.7000                 Shandrani Beachcomber Resort & Spa
# 8    106.6381                           Kost Mewah (Mepet Sawah)
# 9   -139.0333                                        Villa Enata
# 10    78.5000                                      Prithvi Lodge
# 11   100.3354                                     Cititel Penang
# 12  -120.4579           Holiday Inn Express Lompoc, an IHG Hotel
# 13    77.8000                                       MS RESIDENCY
# 14    57.7625                             Sunrise Attitude Hotel
# 15  -155.0900                                Hilo Hawaiian Hotel
# 16   139.5000                          ibis Styles Mt Isa Verona
# 17    73.0833                                  Scoop Guest House
# 18   -90.7195                        Courtyard by Marriott Houma
# 19    34.7642                                           OlusHome
# 20   118.9707                                 Kost Putri RABBANI
# 21   -52.9500                     ALETHEIA Appartement Sinnamary
# 22    13.5456                          Casa Rosa Hotel Residence
# 23   -34.8339                                      Hotel Pigalle
# 24   102.2655                               Grage Hotel Bengkulu
# 25   -34.8553                           Flat Quatro Rodas Olinda
# 26   -40.2925                               Hotel Vitória Palace
# 27   -59.7968                                       Savannah Inn
# 28   -97.5169                                 Motel 6 Sinton, TX
# 29  -159.7750                                       Paradise Inn
# 30   147.7407                                  Daito Guest House
# 31  -159.3190                Sheraton Kauai Coconut Beach Resort
# 32   121.9420                                                NaN
name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_start = vacation_df.loc[[38]]
vacation_start
# Out:
#     City_ID          City Country  Max Temp Current Description     Lat  \
# 38      128  Puerto Ayora      EC     78.76          light rain -0.7393
#
#         Lng                 Hotel Name
# 38 -90.3518  Finch Bay Galapagos Hotel

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[[110]]
vacation_end = vacation_df.loc[[110]]
vacation_stop1 = vacation_df.loc[[152]]
vacation_stop2 = vacation_df.loc[[112]]
vacation_stop3 = vacation_df.loc[[33]]

# %%
vacation_start
# Out:
#      City_ID      City Country  Max Temp Current Description   Lat      Lng  \
# 110      365  Paracuru      BR     82.11     overcast clouds -3.41 -39.0306
#
#              Hotel Name
# 110  Hotel Vento Brasil

# %%
vacation_end
# Out:
#      City_ID      City Country  Max Temp Current Description   Lat      Lng  \
# 110      365  Paracuru      BR     82.11     overcast clouds -3.41 -39.0306
#
#              Hotel Name
# 110  Hotel Vento Brasil

# %%
vacation_stop1
# Out:
#      City_ID        City Country  Max Temp Current Description    Lat    Lng  \
# 152      513  Carutapera      BR     76.66       moderate rain -1.195 -46.02
#
#     Hotel Name
# 152     Lidera

# %%
vacation_stop2
# Out:
#      City_ID         City Country  Max Temp Current Description     Lat  \
# 112      370  Salinopolis      BR     78.15       moderate rain -0.6136
#
#          Lng                          Hotel Name
# 112 -47.3561  Salinas Park Resort Maçarico AP101

# %%
vacation_stop3
# Out:
#     City_ID     City Country  Max Temp Current Description  Lat    Lng  \
# 33      115  Prainha      BR     76.14       moderate rain -1.8 -53.48
#
#     Hotel Name
# 33  Casa Rocha

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.to_numpy()[0][5]+vacation_start.to_numpy()[0][6]
start
#end = 
#stop1 = 
#stop2 = 
#stop3 =
# Out:
# -42.4406

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([],ignore_index=True)
itinerary_df

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

# 11b. Display the figure
