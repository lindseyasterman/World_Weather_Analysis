# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Import the requests library.
import requests
 
# Import the API key.
weather_api_key = "c2a192d87f53861a15f35d0edc7ce199"

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(40)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | touros
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | taonan
# Processing Record 4 of Set 1 | tinaquillo
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | kiama
# Processing Record 7 of Set 1 | narsaq
# Processing Record 8 of Set 1 | riyadh
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | labuhan
# Processing Record 15 of Set 1 | gamba
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | ahipara
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | bourne
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | qarayeri
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | burns lake
# Processing Record 24 of Set 1 | peniche
# Processing Record 25 of Set 1 | charagua
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | gunjur
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | teluknaga
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | sao joao da barra
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | madanapalle
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | sabha
# Processing Record 50 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | lompoc
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | chenzhou
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | nahavand
# Processing Record 8 of Set 2 | vestmannaeyjar
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | gadwal
# Processing Record 11 of Set 2 | nsanje
# Processing Record 12 of Set 2 | tura
# Processing Record 13 of Set 2 | rock springs
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | muros
# Processing Record 16 of Set 2 | quatre cocos
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | yar-sale
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | mount isa
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | beloha
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | arcata
# Processing Record 28 of Set 2 | houma
# Processing Record 29 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | bud
# Processing Record 32 of Set 2 | gat
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | vila franca do campo
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | calama
# Processing Record 37 of Set 2 | rio grande
# Processing Record 38 of Set 2 | obuasi
# Processing Record 39 of Set 2 | majene
# Processing Record 40 of Set 2 | klyuchi
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | baoqing
# Processing Record 43 of Set 2 | sinnamary
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | mosquera
# Processing Record 46 of Set 2 | lobito
# Processing Record 47 of Set 2 | algiers
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | cabedelo
# Processing Record 50 of Set 2 | nouadhibou
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | olinda
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | praia da vitoria
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | lethem
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | kokoda
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | opportunity
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | baiyin
# Processing Record 20 of Set 3 | koyilandi
# City not found. Skipping...
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 3 | nenjiang
# Processing Record 24 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 3 | wake forest
# Processing Record 26 of Set 3 | malayal
# Processing Record 27 of Set 3 | sisimiut
# Processing Record 28 of Set 3 | prainha
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | beyneu
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | bandar-e lengeh
# Processing Record 34 of Set 3 | payakumbuh
# Processing Record 35 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 3 | garautha
# Processing Record 37 of Set 3 | jamestown
# Processing Record 38 of Set 3 | shintomi
# Processing Record 39 of Set 3 | samarai
# Processing Record 40 of Set 3 | port-gentil
# Processing Record 41 of Set 3 | imbituba
# Processing Record 42 of Set 3 | simbakoro
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 3 | broken hill
# Processing Record 46 of Set 3 | mehamn
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | dutse
# Processing Record 50 of Set 3 | poso
# Processing Record 1 of Set 4 | palmer
# Processing Record 2 of Set 4 | wewak
# Processing Record 3 of Set 4 | asau
# Processing Record 4 of Set 4 | vao
# Processing Record 5 of Set 4 | lokoja
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | chanika
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | longjiang
# Processing Record 10 of Set 4 | leshukonskoye
# Processing Record 11 of Set 4 | cedar city
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | ayan
# Processing Record 14 of Set 4 | oistins
# Processing Record 15 of Set 4 | daru
# Processing Record 16 of Set 4 | dicabisagan
# Processing Record 17 of Set 4 | hay river
# Processing Record 18 of Set 4 | caravelas
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | auki
# Processing Record 21 of Set 4 | marzuq
# Processing Record 22 of Set 4 | burica
# City not found. Skipping...
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | nyurba
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | marawi
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | aklavik
# Processing Record 29 of Set 4 | alice springs
# Processing Record 30 of Set 4 | padang
# Processing Record 31 of Set 4 | wattegama
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | kaeo
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | kudahuvadhoo
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | namatanai
# Processing Record 38 of Set 4 | harper
# Processing Record 39 of Set 4 | butaritari
# Processing Record 40 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | wagar
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 4 | half moon bay
# Processing Record 45 of Set 4 | buala
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | sabinas hidalgo
# Processing Record 50 of Set 4 | hvolsvollur
# Processing Record 1 of Set 5 | te anau
# Processing Record 2 of Set 5 | synya
# Processing Record 3 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 4 of Set 5 | dourbali
# Processing Record 5 of Set 5 | trelew
# Processing Record 6 of Set 5 | savannakhet
# Processing Record 7 of Set 5 | qingyuan
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | ratnagiri
# Processing Record 10 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 11 of Set 5 | basco
# Processing Record 12 of Set 5 | seidu
# Processing Record 13 of Set 5 | tchibanga
# Processing Record 14 of Set 5 | tikapur
# Processing Record 15 of Set 5 | basyanovskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | ust-ishim
# Processing Record 17 of Set 5 | paengaroa
# Processing Record 18 of Set 5 | bestobe
# Processing Record 19 of Set 5 | berdigestyakh
# Processing Record 20 of Set 5 | luoyang
# Processing Record 21 of Set 5 | zhaozhou
# Processing Record 22 of Set 5 | isla mujeres
# Processing Record 23 of Set 5 | esperance
# Processing Record 24 of Set 5 | berlevag
# Processing Record 25 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 26 of Set 5 | qaqortoq
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | maningrida
# Processing Record 30 of Set 5 | dasoguz
# Processing Record 31 of Set 5 | alekseyevsk
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | wuda
# Processing Record 34 of Set 5 | korla
# Processing Record 35 of Set 5 | manavalakurichi
# Processing Record 36 of Set 5 | kyra
# Processing Record 37 of Set 5 | taltal
# Processing Record 38 of Set 5 | ponta do sol
# Processing Record 39 of Set 5 | chulumani
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | horizontina
# Processing Record 42 of Set 5 | kameshkovo
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 5 | novyy urgal
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | eureka
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | urambo
# Processing Record 1 of Set 6 | fairbanks
# Processing Record 2 of Set 6 | saint cloud
# Processing Record 3 of Set 6 | bezhetsk
# Processing Record 4 of Set 6 | havoysund
# Processing Record 5 of Set 6 | itoman
# Processing Record 6 of Set 6 | nikolskoye
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | dudinka
# Processing Record 9 of Set 6 | saint-joseph
# Processing Record 10 of Set 6 | ternate
# Processing Record 11 of Set 6 | presidencia roque saenz pena
# Processing Record 12 of Set 6 | road town
# Processing Record 13 of Set 6 | tawzar
# City not found. Skipping...
# Processing Record 14 of Set 6 | hammerfest
# Processing Record 15 of Set 6 | najran
# Processing Record 16 of Set 6 | port moresby
# Processing Record 17 of Set 6 | goundi
# Processing Record 18 of Set 6 | champasak
# Processing Record 19 of Set 6 | boyolangu
# Processing Record 20 of Set 6 | matara
# Processing Record 21 of Set 6 | saint-pierre
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | la carlota
# Processing Record 24 of Set 6 | nizhnevartovsk
# Processing Record 25 of Set 6 | urumqi
# Processing Record 26 of Set 6 | verkhoyansk
# Processing Record 27 of Set 6 | xining
# Processing Record 28 of Set 6 | zlobin
# Processing Record 29 of Set 6 | gizo
# Processing Record 30 of Set 6 | flinders
# Processing Record 31 of Set 6 | ojinaga
# Processing Record 32 of Set 6 | chuy
# Processing Record 33 of Set 6 | hami
# Processing Record 34 of Set 6 | pokhara
# Processing Record 35 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 6 | oxbow
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | neiafu
# Processing Record 39 of Set 6 | taksimo
# Processing Record 40 of Set 6 | matay
# Processing Record 41 of Set 6 | batemans bay
# Processing Record 42 of Set 6 | faanui
# Processing Record 43 of Set 6 | coruripe
# Processing Record 44 of Set 6 | antofagasta
# Processing Record 45 of Set 6 | saint-augustin
# Processing Record 46 of Set 6 | kofele
# Processing Record 47 of Set 6 | moranbah
# Processing Record 48 of Set 6 | singkawang
# Processing Record 49 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 6 | de-kastri
# Processing Record 1 of Set 7 | lahad datu
# Processing Record 2 of Set 7 | gazanjyk
# Processing Record 3 of Set 7 | kefamenanu
# Processing Record 4 of Set 7 | riviere-au-renard
# Processing Record 5 of Set 7 | alamogordo
# Processing Record 6 of Set 7 | muzaffarpur
# Processing Record 7 of Set 7 | honavar
# Processing Record 8 of Set 7 | tieling
# Processing Record 9 of Set 7 | ordzhonikidze
# Processing Record 10 of Set 7 | khatanga
# Processing Record 11 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 7 | aswan
# Processing Record 13 of Set 7 | kiruna
# Processing Record 14 of Set 7 | letterkenny
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | fortuna
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | zhanaozen
# Processing Record 19 of Set 7 | pacific grove
# Processing Record 20 of Set 7 | lady frere
# Processing Record 21 of Set 7 | beroroha
# Processing Record 22 of Set 7 | margate
# Processing Record 23 of Set 7 | roma
# Processing Record 24 of Set 7 | bilibino
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | cochabamba
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | tsentralnyy
# City not found. Skipping...
# Processing Record 29 of Set 7 | cairns
# Processing Record 30 of Set 7 | menongue
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | barcelos
# Processing Record 33 of Set 7 | sandpoint
# Processing Record 34 of Set 7 | isetskoye
# Processing Record 35 of Set 7 | strezhevoy
# Processing Record 36 of Set 7 | prado
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | hazorasp
# Processing Record 39 of Set 7 | birao
# Processing Record 40 of Set 7 | cherskiy
# Processing Record 41 of Set 7 | hanmer springs
# Processing Record 42 of Set 7 | la asuncion
# Processing Record 43 of Set 7 | oranjemund
# Processing Record 44 of Set 7 | armidale
# Processing Record 45 of Set 7 | kruisfontein
# Processing Record 46 of Set 7 | presque isle
# Processing Record 47 of Set 7 | jardim
# Processing Record 48 of Set 7 | manaure
# Processing Record 49 of Set 7 | inongo
# Processing Record 50 of Set 7 | ler
# Processing Record 1 of Set 8 | kulhudhuffushi
# Processing Record 2 of Set 8 | rudnogorsk
# Processing Record 3 of Set 8 | ous
# Processing Record 4 of Set 8 | gold coast
# Processing Record 5 of Set 8 | paamiut
# Processing Record 6 of Set 8 | sangmelima
# Processing Record 7 of Set 8 | butembo
# Processing Record 8 of Set 8 | vence
# Processing Record 9 of Set 8 | jaen
# Processing Record 10 of Set 8 | ust-kuyga
# Processing Record 11 of Set 8 | minna
# Processing Record 12 of Set 8 | kuching
# Processing Record 13 of Set 8 | arman
# Processing Record 14 of Set 8 | ugoofaaru
# Processing Record 15 of Set 8 | inirida
# Processing Record 16 of Set 8 | sandy bay
# Processing Record 17 of Set 8 | kagadi
# Processing Record 18 of Set 8 | baijiantan
# Processing Record 19 of Set 8 | yerbogachen
# Processing Record 20 of Set 8 | celestun
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | fukuma
# Processing Record 23 of Set 8 | jacareacanga
# Processing Record 24 of Set 8 | sakakah
# Processing Record 25 of Set 8 | vostok
# Processing Record 26 of Set 8 | jermuk
# Processing Record 27 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 8 | bauchi
# Processing Record 29 of Set 8 | danjiangkou
# Processing Record 30 of Set 8 | pisco
# Processing Record 31 of Set 8 | hobyo
# Processing Record 32 of Set 8 | berdyuzhye
# City not found. Skipping...
# Processing Record 33 of Set 8 | nome
# Processing Record 34 of Set 8 | stephenville
# Processing Record 35 of Set 8 | severnoye
# Processing Record 36 of Set 8 | folldal
# Processing Record 37 of Set 8 | palasa
# Processing Record 38 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 39 of Set 8 | sioux lookout
# Processing Record 40 of Set 8 | uruzgan
# Processing Record 41 of Set 8 | hanyang
# Processing Record 42 of Set 8 | tatawin
# Processing Record 43 of Set 8 | mareeba
# Processing Record 44 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 8 | port blair
# Processing Record 46 of Set 8 | villa carlos paz
# Processing Record 47 of Set 8 | skjervoy
# Processing Record 48 of Set 8 | cabo san lucas
# Processing Record 49 of Set 8 | chokurdakh
# Processing Record 50 of Set 8 | hambantota
# Processing Record 1 of Set 9 | wakkanai
# Processing Record 2 of Set 9 | paracuru
# Processing Record 3 of Set 9 | isangel
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | san jeronimo
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | salinopolis
# Processing Record 8 of Set 9 | umm lajj
# Processing Record 9 of Set 9 | avera
# Processing Record 10 of Set 9 | chumikan
# Processing Record 11 of Set 9 | hervey bay
# Processing Record 12 of Set 9 | fort nelson
# Processing Record 13 of Set 9 | marsa matruh
# Processing Record 14 of Set 9 | cap malheureux
# Processing Record 15 of Set 9 | sadasivpet
# Processing Record 16 of Set 9 | sur
# Processing Record 17 of Set 9 | tiznit
# Processing Record 18 of Set 9 | plouzane
# Processing Record 19 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 9 | sistranda
# Processing Record 21 of Set 9 | mantua
# Processing Record 22 of Set 9 | ouidah
# Processing Record 23 of Set 9 | muborak
# Processing Record 24 of Set 9 | rapid valley
# Processing Record 25 of Set 9 | castelnaudary
# Processing Record 26 of Set 9 | progreso
# Processing Record 27 of Set 9 | riberalta
# Processing Record 28 of Set 9 | araguacu
# Processing Record 29 of Set 9 | am timan
# Processing Record 30 of Set 9 | mananjary
# Processing Record 31 of Set 9 | surt
# Processing Record 32 of Set 9 | provideniya
# Processing Record 33 of Set 9 | wuwei
# Processing Record 34 of Set 9 | lata
# Processing Record 35 of Set 9 | kamalpur
# Processing Record 36 of Set 9 | abu kamal
# Processing Record 37 of Set 9 | santiago
# Processing Record 38 of Set 9 | nykoping
# Processing Record 39 of Set 9 | san diego
# Processing Record 40 of Set 9 | farafangana
# Processing Record 41 of Set 9 | meulaboh
# Processing Record 42 of Set 9 | naze
# Processing Record 43 of Set 9 | srandakan
# Processing Record 44 of Set 9 | lukovetskiy
# Processing Record 45 of Set 9 | kenai
# Processing Record 46 of Set 9 | kloulklubed
# Processing Record 47 of Set 9 | galbshtadt
# Processing Record 48 of Set 9 | yulara
# Processing Record 49 of Set 9 | ponferrada
# Processing Record 50 of Set 9 | dickinson
# Processing Record 1 of Set 10 | miyako
# Processing Record 2 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 10 | shimoda
# Processing Record 4 of Set 10 | tromso
# Processing Record 5 of Set 10 | kahului
# Processing Record 6 of Set 10 | vrangel
# Processing Record 7 of Set 10 | uyuni
# Processing Record 8 of Set 10 | paris
# Processing Record 9 of Set 10 | kununurra
# Processing Record 10 of Set 10 | salym
# Processing Record 11 of Set 10 | winnemucca
# Processing Record 12 of Set 10 | whyalla
# Processing Record 13 of Set 10 | beringovskiy
# Processing Record 14 of Set 10 | tual
# Processing Record 15 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 10 | seoul
# Processing Record 17 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 10 | hebi
# Processing Record 19 of Set 10 | rockford
# Processing Record 20 of Set 10 | new iberia
# Processing Record 21 of Set 10 | moyale
# Processing Record 22 of Set 10 | ostrovnoy
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | dingle
# Processing Record 25 of Set 10 | black river
# Processing Record 26 of Set 10 | cap-aux-meules
# Processing Record 27 of Set 10 | saint-pie
# Processing Record 28 of Set 10 | ixtapa
# Processing Record 29 of Set 10 | kargil
# Processing Record 30 of Set 10 | sampit
# Processing Record 31 of Set 10 | shelburne
# Processing Record 32 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 10 | kavaratti
# Processing Record 34 of Set 10 | khani
# Processing Record 35 of Set 10 | solginskiy
# Processing Record 36 of Set 10 | asosa
# Processing Record 37 of Set 10 | aykhal
# Processing Record 38 of Set 10 | moussoro
# Processing Record 39 of Set 10 | ostersund
# Processing Record 40 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 10 | ondjiva
# Processing Record 42 of Set 10 | turukhansk
# Processing Record 43 of Set 10 | mnogovershinnyy
# Processing Record 44 of Set 10 | los llanos de aridane
# Processing Record 45 of Set 10 | yaan
# Processing Record 46 of Set 10 | pangkalanbuun
# Processing Record 47 of Set 10 | ilhabela
# Processing Record 48 of Set 10 | canutama
# Processing Record 49 of Set 10 | biltine
# Processing Record 50 of Set 10 | belyy yar
# Processing Record 1 of Set 11 | rudbar
# Processing Record 2 of Set 11 | victoria point
# Processing Record 3 of Set 11 | santa cruz
# Processing Record 4 of Set 11 | kotelnich
# Processing Record 5 of Set 11 | vanimo
# Processing Record 6 of Set 11 | sao sebastiao
# Processing Record 7 of Set 11 | silvania
# Processing Record 8 of Set 11 | juneau
# Processing Record 9 of Set 11 | eyl
# Processing Record 10 of Set 11 | gobabis
# Processing Record 11 of Set 11 | puerto leguizamo
# Processing Record 12 of Set 11 | pangai
# Processing Record 13 of Set 11 | manta
# Processing Record 14 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 11 | boa vista
# Processing Record 16 of Set 11 | barahona
# Processing Record 17 of Set 11 | pushkinskiye gory
# Processing Record 18 of Set 11 | nemuro
# Processing Record 19 of Set 11 | springbok
# Processing Record 20 of Set 11 | iquitos
# Processing Record 21 of Set 11 | sorland
# Processing Record 22 of Set 11 | zhuozhou
# City not found. Skipping...
# Processing Record 23 of Set 11 | rio bueno
# Processing Record 24 of Set 11 | altay
# Processing Record 25 of Set 11 | nalut
# Processing Record 26 of Set 11 | kenora
# Processing Record 27 of Set 11 | manokwari
# Processing Record 28 of Set 11 | lafiagi
# Processing Record 29 of Set 11 | maltahohe
# Processing Record 30 of Set 11 | brae
# Processing Record 31 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | kuminskiy
# Processing Record 34 of Set 11 | santa barbara
# Processing Record 35 of Set 11 | lakes entrance
# Processing Record 36 of Set 11 | truro
# Processing Record 37 of Set 11 | ornskoldsvik
# Processing Record 38 of Set 11 | cidreira
# Processing Record 39 of Set 11 | laukaa
# Processing Record 40 of Set 11 | san quintin
# Processing Record 41 of Set 11 | novonikolsk
# Processing Record 42 of Set 11 | colquechaca
# Processing Record 43 of Set 11 | fort dix
# Processing Record 44 of Set 11 | pasighat
# Processing Record 45 of Set 11 | marsabit
# Processing Record 46 of Set 11 | krasnoselkup
# Processing Record 47 of Set 11 | tautira
# Processing Record 48 of Set 11 | deputatskiy
# Processing Record 49 of Set 11 | salta
# Processing Record 50 of Set 11 | taraz
# Processing Record 1 of Set 12 | bubaque
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | istisu
# Processing Record 4 of Set 12 | grand gaube
# Processing Record 5 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 12 | katangli
# Processing Record 7 of Set 12 | along
# Processing Record 8 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 12 | erdenet
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 12 | rosetta
# Processing Record 12 of Set 12 | carutapera
# Processing Record 13 of Set 12 | makakilo city
# Processing Record 14 of Set 12 | tabou
# Processing Record 15 of Set 12 | warrington
# Processing Record 16 of Set 12 | hohhot
# Processing Record 17 of Set 12 | waipawa
# Processing Record 18 of Set 12 | tigil
# Processing Record 19 of Set 12 | parksville
# Processing Record 20 of Set 12 | lagoa
# Processing Record 21 of Set 12 | swift current
# Processing Record 22 of Set 12 | itaqui
# Processing Record 23 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 12 | marsala
# Processing Record 25 of Set 12 | sitka
# Processing Record 26 of Set 12 | brownsville
# Processing Record 27 of Set 12 | sola
# Processing Record 28 of Set 12 | leh
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | northam
# Processing Record 31 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 12 | komsomolskiy
# Processing Record 33 of Set 12 | floro
# Processing Record 34 of Set 12 | katobu
# Processing Record 35 of Set 12 | mingshui
# Processing Record 36 of Set 12 | vertientes
# Processing Record 37 of Set 12 | svetlaya
# Processing Record 38 of Set 12 | langsa
# Processing Record 39 of Set 12 | lermontovka
# Processing Record 40 of Set 12 | lastoursville
# Processing Record 41 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 42 of Set 12 | morwell
# Processing Record 43 of Set 12 | ikalamavony
# Processing Record 44 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 45 of Set 12 | karwar
# Processing Record 46 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 12 | komsomolets
# Processing Record 48 of Set 12 | port augusta
# Processing Record 49 of Set 12 | portland
# Processing Record 50 of Set 12 | burnie
# Processing Record 1 of Set 13 | la ronge
# Processing Record 2 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 3 of Set 13 | bermeo
# Processing Record 4 of Set 13 | changying
# Processing Record 5 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 6 of Set 13 | pitimbu
# Processing Record 7 of Set 13 | grenada
# Processing Record 8 of Set 13 | boca del monte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 553

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Touros  -5.1989  -35.4608     79.88        79          65
# 1   New Norfolk -42.7826  147.0587     55.65        69         100
# 2        Taonan  45.3333  122.7833     44.83        28           6
# 3    Tinaquillo   9.9186  -68.3047     77.07        92         100
# 4  Punta Arenas -53.1500  -70.9167     46.51        93          75
# 5         Kiama -34.6833  150.8667     74.25        71          72
# 6        Narsaq  60.9167  -46.0500     34.02        91          92
# 7        Riyadh  24.6877   46.7219     69.94        21           0
# 8       Mataura -46.1927  168.8643     53.47        59           1
# 9   Port Alfred -33.5906   26.8910     59.18        91          16
#
#    Wind Speed Country Current Description
# 0        7.76      BR       broken clouds
# 1        1.99      AU     overcast clouds
# 2        4.76      CN           clear sky
# 3        1.61      VE          light rain
# 4        2.30      CL          light rain
# 5        6.02      AU       broken clouds
# 6        4.81      GL     overcast clouds
# 7        5.99      SA           clear sky
# 8        2.68      NZ           clear sky
# 9        1.99      ZA          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
